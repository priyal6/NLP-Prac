# %% [markdown]
# <a href="https://colab.research.google.com/github/priyal6/NLP-Prac/blob/main/text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install nltk rouge-score bert-score transformers
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 2.7 MB/s eta 0:00:00
# ...
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=d6d3c842581ee9c445b54b2efb388bd21cd464cdfc14d2253815e2ab141e785c
#   Stored in directory: /root/.cache/pip/wheels/85/9d/af/01feefbe7d55ef5468796f0c68225b6788e85d9d0a281e7a70
# Successfully built rouge-score
# ...

# %%
candidate = "the cat is on the mat"
reference = "the cat is sitting on the mat"

# %%
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

candidate = "the cat is on the mat".split()
reference = ["the cat is sitting on the map".split()]


smooth = SmoothingFunction().method1
bleu = sentence_bleu(reference, candidate, smoothing_function = smooth)

print("BLEU Score:", bleu)
# Out:
# BLEU Score: 0.21506254256566312

# %%
from rouge_score import rouge_scorer

candidate = "the cat is on the mat"
reference = "the cat is sitting on the mat"

scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
scores = scorer.score(reference, candidate)


print("ROUGE-1:", scores['rouge1'])
print("ROUGE-2:", scores['rouge2'])
print("ROUGE-L:", scores['rougeL'])
# Out:
# ROUGE-1: Score(precision=1.0, recall=0.8571428571428571, fmeasure=0.923076923076923)
# ROUGE-2: Score(precision=0.8, recall=0.6666666666666666, fmeasure=0.7272727272727272)
# ROUGE-L: Score(precision=1.0, recall=0.8571428571428571, fmeasure=0.923076923076923)

# %%
from bert_score import score

candidate = ["the cat is on the mat"]
reference = ["the cat is sitting on the mat"]

P, R, F1 = score(candidate, reference, lang="en", verbose=True)

print("BERT-Score P:", P.item())
print("BERT-Score R:", R.item())
print("BERT-Score F1:", F1.item())
# Out:
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 0.59 seconds, 1.69 sentences/sec

# %%
print("BERT-Score P:", P.item())
print("BERT-Score R:", R.item())
print("BERT-Score F1:", F1.item())
# Out:
# BERT-Score P: 0.9301672577857971
# BERT-Score R: 0.9176854491233826
# BERT-Score F1: 0.9238842129707336

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch
import math

model_name = "gpt2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

sentence = "The cat is sitting on the mat."

inputs = tokenizer(sentence, return_tensors = "pt")
with torch.no_grad():
  outputs = model(**inputs, labels =inputs["input_ids"])
  loss = outputs.loss

perplexity = math.exp(loss.item())
print("Perplexity:", perplexity)
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# `loss_type=None` was set in the config but it is unrecognized. Using the default loss: `ForCausalLMLoss`.
# Perplexity: 45.5331845544402
